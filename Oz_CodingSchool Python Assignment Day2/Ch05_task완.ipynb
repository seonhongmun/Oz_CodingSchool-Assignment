# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```Python으로 변수를 생성하는 방법으로 올바른 것을 고르세요```
#
# 1. number == 20
# 2. 100 == number
# 3. number(7)
# 4. number = 7

# %%
number == 20
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ffa1977cd484> in <cell line: 1>()
# ----> 1 number == 20
#
# NameError: name 'number' is not defined

# %%
100 == number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-66cbf5ca83b6> in <cell line: 1>()
# ----> 1 100 == number
#
# NameError: name 'number' is not defined

# %%
number(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2d052d5d87a4> in <cell line: 1>()
# ----> 1 number(7)
#
# TypeError: 'int' object is not callable

# %%
number = 7

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 4. number = 7

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```다음 중 올바르지 않은 것을 골라주세요```
#
# 이름 = "김오즈"<br>
# 나이 = 14<br>
# 소속 = "마법중"<br>
# 등급 = 3<br>
#
# 1. 이름 + 소속
# 2. 나이 + 등급
# 3. 소속 + 등급

# %%
이름 = "김오즈"
나이 = 14
소속 = "마법중"
등급 = 3

print(이름 + 소속) #문자열 + 문자열
# Out:
# 김오즈마법중

# %%
print(나이 + 등급) #정수열 + 정수열
# Out:
# 17

# %%
print(소속 + 등급) #정수열 + 문자열 XXXX
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e1b6fa759c31> in <cell line: 1>()
# ----> 1 print(소속 + 등급)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3. 소속 + 등급

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```아래 변수의 type으로 올바른것을 골라주세요```
#
# 퀴즈 = "스페인에서 카리나를 보고 하는 말은?"<br>
# type(퀴즈)

# %%
퀴즈 = "스페인에서 카리나를 보고 하는 말은?"
type(퀴즈)
# Out:
# str

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# str(문자열)

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```다음 중 변수 이름으로 사용할 수 없는 것을 모두 골라주세요```
#
# 1. 78abc
# 2. ABC
# 3. _ABC
# 4. _hello%2
# 5. for

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1. 78abc
# 4. _hello%2
# 5. for
# #변수를 만드는 규칙
# #영문 문자와 숫자를 사용할 수 있습니다.
# #대소문자를 구분합니다.
# #첫글자는 대문자로 쓰는걸 지향합니다.
# #문자부터 시작해야 하며 숫자부터 시작하면 안됩니다.
# #_(밑줄문자)로 시작할수 있습니다.
# #특수문자(+ , -, *, /, $,@, &, %)는 사용할수 없습니다.
# #파이썬의 키워드 (if, for, while, and, or등)는 사용할수 없습니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```다음 중 변수와 연산자의 사용 방법으로 올바르지 않은 것을 모두 골라주세요```
#
# x = 3
# y = 7
#
# 1. x = x + y
# 2. x // 2
# 3. z >< x
# 4. y += x
# 5. ++x

# %%
++x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-bdb8b27a69f2> in <cell line: 1>()
# ----> 1 ++x
#
# NameError: name 'x' is not defined

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 5. ++x
# ##++연산자 없음
