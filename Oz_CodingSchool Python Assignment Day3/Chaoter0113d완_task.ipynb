# %% [markdown]
# 안녕하세요. 수강생 여러분~!
#
# Chapter01 ~ 13의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다 !
#
# 지금까지 잘 해오셨으니까, 총 복습한다고 생각하시고 한번 도전해보세요 !!!
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# ### 프로젝트: 간단한 ATM 관리 시스템
# <br>
#
# __[문제 1: 잔액 확인]__
#
# 현재 잔액은 1000원입니다. 현재 잔액을 출력하세요.
#
# (변수명 예시 : 잔액 - balance)

# %%
balance = 1000
print(f"현재 금액: {balance}원")
# Out:
# 현재 금액: 1000원

# %% [markdown]
# __[문제 2: 입금]__
#
# 가지고 있는 돈을 입금합니다.
#
# 입금 금액을 입력받고, 잔액을 갱신한 후 새로운 잔액을 출력하세요. 입금 거래를 영수증 리스트에 기록하세요.
#
# - 입금 금액은 input()을 이용해 받습니다.
# - 영수증은 list()로 선언합니다.
# - 영수증에 들어가는 정보는 튜플 형태입니다.
# - 튜플에 담기는 정보는 (입금 or 출금, 입금 or 출금 금액, 현재 잔액)순 입니다.
#
# (변수명 예시: 영수증 리스트 - receipts, 입금 금액 - deposit_amount)

# %%
#입금기능
receipts = []
deposit_amount = int(input("입금할 금액을 입력해주세요 : ")) #3000 문자형태 "3000" 그렇기에 int()추가
balance += deposit_amount   #balance에 입금한 금액을 더하고 삽입한다.
receipts.append(("입금", deposit_amount ,balance))
print(f'입금이 완료되었습니다. 입금하신 금액은 {deposit_amount}원이고, 계좌 총 잔액은 {[balance]}원 입니다.')
# Out:
# 입금할 금액을 입력해주세요 : 300000
# 입금이 완료되었습니다. 입금하신 금액은 300000원이고, 계좌 총 잔액은 [331000]원 입니다.

# %% [markdown]
# __[문제 3: 출금]__
#
# 사용자가 돈을 출금합니다. 출금 금액을 입력받고, 잔액을 갱신한 후 새로운 잔액을 출력하세요. 출금 거래를 영수증 리스트에 기록하세요.
#
# - 출금 금액은 input()을 이용해 받습니다.
# - 현재 잔액보다 출금 요청 금액이 많을 경우 현재 잔액 만큼만 출금되도록 합니다.
# - 영수증에 들어가는 정보는 튜플 형태입니다.
# - 튜플에 담기는 정보는 (입금 or 출금, 입금 or 출금 금액, 현재 잔액)순 입니다.
#
# (변수명 예시: 출금금액 - withdraw_amount)

# %%
#출금기능
withdraw_amount  = int(input("출금할 금액을 입력해주세요 : ")) #출금금액 input
withdraw_amount = min(balance, withdraw_amount) #
balance -= withdraw_amount   #balance에 입금한 금액을 더하고 삽입한다.
receipts.append(("출금", withdraw_amount ,balance))
print(f'출금이 완료되었습니다 출금하신 금액은 {withdraw_amount}원이고, 계좌 총 잔액은 {[balance]}원 입니다.')
# Out:
# 출금할 금액을 입력해주세요 : 5000
# 출금이 완료되었습니다 출금하신 금액은 5000원이고, 계좌 총 잔액은 [326000]원 입니다.

# %% [markdown]
# __[문제 4: 모든 거래 내역 확인]__
#
# 모든 거래 내역(영수증)을 요청받았을 때 출력하세요.
# - 지금까지 영수증에 추가된 정보를 출력합니다.
# - 출력 형태는 자유입니다.

# %%
#영수증
print("모든 거래 내역을 보여드립니다.", receipts)
# Out:
# 모든 거래 내역을 보여드립니다. [('입금', 300000, 331000), ('출금', 5000, 326000)]
