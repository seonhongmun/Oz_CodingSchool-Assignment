# %% [markdown]
# 안녕하세요. 수강생 여러분~!
#
# 다시 돌아온 조금 더 성장할 기 ! 회 !
#
# Chapter01 ~ 16의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다 !
#
# 지금까지 잘 해오셨으니까, 총 복습한다고 생각하시고 한번 도전해보세요 !!!
#
# 차근 차근 문제와 요구사항을 읽고 작성해보세요.
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# #### 프로젝트: 붕어빵 자동 판매 시스템
#
#
# 당신은 붕어빵 가게의 주인입니다.
#
# 손님들이 붕어빵을 주문하면 이를 자동으로 처리하고, 재고를 관리하는 시스템을 만들고자 합니다.
#
# 또한, 관리자 모드를 통해 재고를 추가할 수 있는 기능을 구현해야 합니다.

# %% [markdown]
# __[문제 1: 붕어빵 재고 확인]__
#
# 붕어빵 가게의 현재 재고를 확인하는 기능을 구현하세요.
#
# 요구사항:
# - 현재 붕어빵의 재고를 딕셔너리로 관리합니다.
# - 딕셔너리에는 붕어빵의 종류와 각각의 재고 개수가 저장됩니다.
# - 현재 재고를 화면에 출력하세요.
#
# 붕어빵 재고
# - 팥붕어빵 : 10개
# - 슈크림붕어빵 : 8개
# - 초코붕어빵 : 5개

# %%
재고 = {"팥붕어빵" : "10개", "슈크림붕어빵" : "8개", "초코붕어빵" : "5개"}
재고
# Out:
# {'팥붕어빵': '10개', '슈크림붕어빵': '8개', '초코붕어빵': '5개'}

# %% [markdown]
# __[문제 2: 붕어빵 주문 받기]__
#
# 손님이 주문한 붕어빵의 종류와 개수를 입력받는 기능을 구현하세요.
#
# 요구사항:
# - 손님이 주문할 붕어빵의 종류와 개수를 입력받습니다.
# - 주문 내용을 딕셔너리에 저장하세요.
# - 주문 내역을 출력해주세요.

# %%
주문내역 = []
for i , j in 재고.items():
    개수 = int(input(f'{i}의 개수를 입력해주세요 : '))
    주문내역.append({"물품": i , "개수":개수})
print(주문내역)
# Out:
# 팥붕어빵의 개수를 입력해주세요 : 5
# 슈크림붕어빵의 개수를 입력해주세요 : 10
# 초코붕어빵의 개수를 입력해주세요 : 2
# [{'물품': '팥붕어빵', '개수': '10개'}, {'물품': '슈크림붕어빵', '개수': '8개'}, {'물품': '초코붕어빵', '개수': '5개'}]

# %% [markdown]
# __[문제 3: 붕어빵 주문 처리]__
#
# 손님의 주문을 처리하여 붕어빵 재고를 업데이트하는 기능을 구현하세요.
#
# 요구사항:
# - 손님의 주문 내용을 기반으로 재고를 업데이트합니다.
# - 재고가 부족할 경우, 손님에게 재고 부족을 알리고 재고를 감소시키지 않습니다.
# - 재고가 충분할 경우, 주문한 만큼 재고를 감소시키고 판매를 완료합니다.
# - 판매가 완료된 경우 판매된 붕어빵 맛과 개수를 출력하세요.

# %%
물품 = {"팥붕어빵" : 10, "슈크림붕어빵" : 8, "초코붕어빵" : 5}
주문내역 = []
for 종류, 개수 in 물품.items():
    주문개수 = int(input(f'{종류}의 개수를 입력해주세요 : '))
    주문내역.append({종류:주문개수})
    if 물품[종류] < 주문개수:
        print(f'{종류}의 재고가 부족합니다.')
    else:
        물품[종류] -= 주문개수
print(f'팥붕어빵 {물품["팥붕어빵"]}개, 슈크림붕어빵 {물품["슈크림붕어빵"]}개, 초코붕어빵 {물품["초코붕어빵"]}개 남았습니다.')
# Out:
# 팥붕어빵의 개수를 입력해주세요 : 10
# 슈크림붕어빵의 개수를 입력해주세요 : 5
# 초코붕어빵의 개수를 입력해주세요 : 6
# 초코붕어빵의 재고가 부족합니다.
# 팥붕어빵 0개, 슈크림붕어빵 3개, 초코붕어빵 5개 남았습니다.

# %% [markdown]
# __[문제 4: 여러 손님 주문 처리]__
#
# 여러 손님들의 주문을 처리할 수 있도록 시스템을 확장하세요.
#
# 요구사항:
# - 손님이 "종료"를 입력할 때까지 주문을 계속 받습니다.
# - 각 주문마다 재고를 업데이트합니다.
# - 현재 재고를 화면에 출력합니다.

# %%
물품 = {"팥붕어빵" : 10, "슈크림붕어빵" : 8, "초코붕어빵" : 5}
주문내역 = []

while True:
    number = input("사용하실 시스템을 선택해주세요 (1:구매  2:관리자  3:종료) : ")
    if number == "1":
        for 종류, 개수 in 물품.items():
            주문개수 = int(input(f'{종류}의 개수를 입력해주세요 : '))
            주문내역.append({종류:주문개수})
            if 물품[종류] < 주문개수:
                print(f'{종류}의 재고가 부족합니다.')
            else:
                물품[종류] -= 주문개수
        print(f'팥붕어빵 {물품["팥붕어빵"]}개, 슈크림붕어빵 {물품["슈크림붕어빵"]}개, 초코붕어빵 {물품["초코붕어빵"]}개 남았습니다.')
    if number == "3":
        print("감사합니다 또 오세요")
        break
# Out:
# 사용하실 시스템을 선택해주세요 (1:구매  2:관리자  3:종료) : 3
# 감사합니다 또 오세요

# %% [markdown]
# __[문제 5: 관리자 모드]__
#
# 관리자 모드를 통해 붕어빵 재고를 추가할 수 있는 기능을 구현하세요.
#
# 요구사항:
# - 관리자는 특정 붕어빵의 재고를 추가할 수 있습니다.
# - "종료"를 입력하면 관리자 모드를 종료합니다.
# - 추가된 재고를 업데이트하고 현재 재고를 화면에 출력합니다.

# %%
    if number == "2":
        print("관리자 모드입니다.")
        number2 = input("원하는 서비스를 입력해주세요. (1:재고추가  2:매출확인  3:종료) : ")
        if number2 == "1":
            print(f'현재 재고는 팥붕어빵:{물품["팥붕어빵"]}개, 슈크림붕어빵:{물품["슈크림붕어빵"]}개, 초코붕어빵:{물품["초코붕어빵"]}개 입니다.')
            추가 = input("맛을 입력해주세요 : ")
            추가개수 = int(input("개수를 입력해주세요 : "))
            물품[추가] += 추가개수
            print(f'{추가}맛을 {추가개수} 개 채워 현재 재고는 {물품[추가]}개 입니다.')

        if number2 == "2":  #매출확인
                print("--------------------------------------------------------")
                for 종류, 개수 in 붕어빵판매.items():
                    print(f'{종류}에 판매개수는 {개수}이고 금액은 {int((개수) * 가격[종류])} 원 입니다.')
                    총금액 += int((개수) * 가격[종류])
                    print("--------------------------------------------------------")
                print(f"총매출은 {총금액}입니다. 오늘 하루도 고생하셨습니다~")

        if number2 == "3":
            print("관리자 모드를 나갑니다. ")
# Out:
# 사용하실 시스템을 선택해주세요 (1:판매  2:관리자  3:종료) : 2
# 관리자 모드입니다.
# 원하는 서비스를 입력해주세요. (1:재고추가  2:맛추가  3:종료) : 1
# 현재 재고는 팥붕어빵:10개, 슈크림붕어빵:8개, 초코붕어빵:5개 입니다.
# 맛을 입력해주세요 : 팥붕어빵
# 개수를 입력해주세요 : 5
# 팥붕어빵맛을 5 개 채워 현재 재고는 15개 입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5d6848a3359c> in <cell line: 4>()
#       3
#       4 while True:
# ----> 5     number = input("사용하실 시스템을 선택해주세요 (1:판매  2:관리자  3:종료) : ")
#       6     if number == "1":
#       7         for 종류, 개수 in 물품.items():
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %% [markdown]
# __[문제 6: 매출 확인]__
#
# 붕어빵 판매 가격을 설정하고, 판매한 붕어빵의 매출을 계산하세요.
#
# 요구사항:
# - 각 붕어빵의 가격을 딕셔너리로 관리합니다.
# - 판매된 붕어빵의 종류와 개수를 딕셔너리로 관리합니다.
# - 총 매출을 계산하여 출력합니다.
#
# 초기 설정:
# - 가격
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - 판매 개수
#     - "팥붕어빵": 0
#     - "슈크림붕어빵": 0
#     - "초코붕어빵": 0

# %%
물품 = {"팥붕어빵" : 10, "슈크림붕어빵" : 8, "초코붕어빵" : 5}
가격 = {"팥붕어빵" : 1000, "슈크림붕어빵" : 1200, "초코붕어빵" : 1500}
붕어빵판매 = {"팥붕어빵" : 0, "슈크림붕어빵" : 0, "초코붕어빵" : 0}
주문내역 = []
총금액 = 0

while True:
    number = input("사용하실 시스템을 선택해주세요 (1:판매  2:관리자  3:종료) : ")
    if number == "1":
        for 종류, 개수 in 물품.items():
            주문개수 = int(input(f'{종류}의 개수를 입력해주세요 : '))
            주문내역.append({종류 : 주문개수})
            if 물품[종류] < 주문개수:
                print(f'{종류}의 재고가 부족합니다.')
                주문개수 = 0
            else:
                print(f'{종류}의 구매가 완료되었습니다.')
                물품[종류] -= 주문개수
                붕어빵판매[종류] += 주문개수
        print(" ----------------------------------")
        print("       현재 재고입니다.                ")
        print(" ----------------------------------")
        for 종류, 개수, in 물품.items():
            print(f'        {종류} : {개수}개       ')
            print(" ----------------------------------")

    if number == "2":
        print("관리자 모드입니다.")
        number2 = input("원하는 서비스를 입력해주세요. (1:재고추가  2:매출확인  3:종료) : ")
        if number2 == "1":
            print(f'현재 재고는 팥붕어빵:{물품["팥붕어빵"]}개, 슈크림붕어빵:{물품["슈크림붕어빵"]}개, 초코붕어빵:{물품["초코붕어빵"]}개 입니다.')
            추가 = input("맛을 입력해주세요 : ")
            추가개수 = int(input("개수를 입력해주세요 : "))
            물품[추가] += 추가개수
            print(f'{추가}맛을 {추가개수} 개 채워 현재 재고는 {물품[추가]}개 입니다.')

        if number2 == "2":  #매출확인
                print("--------------------------------------------------------")
                for 종류, 개수 in 붕어빵판매.items():
                    print(f'{종류}에 판매개수는 {개수}이고 금액은 {int((개수) * 가격[종류])} 원 입니다.')
                    총금액 += int((개수) * 가격[종류])
                    print("--------------------------------------------------------")
                print(f"총매출은 {총금액}입니다. 오늘 하루도 고생하셨습니다~")

        if number2 == "3":
            print("관리자 모드를 나갑니다. ")

    if number == "3":
        print("감사합니다 또 오세요")
        break
# Out:
# 사용하실 시스템을 선택해주세요 (1:판매  2:관리자  3:종료) : 1
# 팥붕어빵의 개수를 입력해주세요 : 3
# 슈크림붕어빵의 개수를 입력해주세요 : 3
# 초코붕어빵의 개수를 입력해주세요 : 3
# 팥붕어빵 7개, 슈크림붕어빵 5개, 초코붕어빵 2개 남았습니다.
# 사용하실 시스템을 선택해주세요 (1:판매  2:관리자  3:종료) : 2
# 관리자 모드입니다.
# 원하는 서비스를 입력해주세요. (1:재고추가  2:매출확인  3:종료) : 2
# ['팥붕어빵', '슈크림붕어빵', '초코붕어빵']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-198ea4caa8a8> in <cell line: 6>()
#       5
#       6 while True:
# ----> 7     number = input("사용하실 시스템을 선택해주세요 (1:판매  2:관리자  3:종료) : ")
#       8     if number == "1":
#       9         for 종류, 개수 in 물품.items():
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
# ...
