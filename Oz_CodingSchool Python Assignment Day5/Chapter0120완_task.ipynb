# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter17 ~ 20 수업은 잘 들으셨나요?
#
# Chapter01 ~ 20의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# 저번에 했던 "붕어빵 자동 판매 시스템"을 리팩토링 해봅시다 !!!
#
# 못해도 괜찮아요 ! 같이 해봅시다 !
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ### 리팩토링 과제
#
# Day4에서 만든 "붕어빵 자동 판매 시스템"은 절차적 코드로 구현되어있습니다.
# <br>
#
# Day5에서 배운 함수, 클래스 개념을 적용시켜 객체지향적으로 리팩토링을 진행해주세요

# %%
# 리팩토링 과제 힌트
# 구조는 아래와 같습니다.
class BungeoppangShop:
    def __init__(self):

    def check_stock(self):

    def process_order(self, bread_type, bread_count):

    def admin_mode(self):

    def calculate_total_sales(self):

def main():

if __name__ == "__main__":
    main()

# %% [markdown]
# __BungeoppangShop 클래스__
#
# - __init__(): 초기 재고, 가격, 판매량을 설정합니다.
# - check_stock(): 현재 재고를 출력합니다.
# - process_order(): 주문을 처리하고 재고를 업데이트합니다.
# - admin_mode(): 관리자 모드에서 재고를 추가합니다.
# - calculate_total_sales(): 총 매출을 계산하고 출력합니다.

# %% [markdown]
# __[과제 1: 초기화 메서드 __init__]__
#
# 목표: __init__ 메서드를 구현하여 붕어빵 가게의 초기 재고, 가격, 판매량을 설정합니다.
#
# 설명: self.stock, self.prices, self.sales 딕셔너리를 초기화하세요.
# - stock
#     - "팥붕어빵": 10
#     - "슈크림붕어빵": 8
#     - "초코붕어빵": 5
#
# - prices
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - sales
#     - "팥붕어빵": 0,
#     - "슈크림붕어빵": 0,
#     - "초코붕어빵": 0

# %%
def __init__(self):
    self.stock = {
        "팥붕어빵": 10,
        "슈크림붕어빵": 8,
        "초코붕어빵": 5
    }
    self.prices = {
        "팥붕어빵": 1000,
        "슈크림붕어빵": 1200,
        "초코붕어빵": 1500
    }
    self.sales = {
        "팥붕어빵": 0,
        "슈크림붕어빵": 0,
        "초코붕어빵": 0
    }

# %% [markdown]
# __[과제 2: 재고 확인 메서드 check_stock]__
#
# 목표: check_stock 함수를 구현하여 현재 붕어빵 재고를 출력합니다.
#
# 설명: self.stock 딕셔너리를 순회하며 각 붕어빵의 종류와 재고를 출력하세요.

# %%
def check_stock(self):
    print("현재 붕어빵 재고:")
    for bread, quantity in self.stock.items():
        print(f"{bread}: {quantity}개")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-9d4e9860d115> in <cell line: 9>()
#       7         for 종류, 개수 in self.qnd.items():
#       8             print(f'현재 {종류}의 재고는 {개수}개 입니다.')
# ----> 9 재고확인()
#
# <ipython-input-64-bd89e05f854e> in 재고확인()
#       1 def 재고확인():
# ----> 2     for 종류, 개수 in qnd.items():
#       3         print(f'현재 {종류}의 재고는 {개수}개 입니다.')
#       4 재고확인()
#
# NameError: name 'qnd' is not defined

# %% [markdown]
# __[과제 3: 주문 처리 메서드 process_order]__
#
# 목표: process_order 함수를 구현하여 손님의 주문을 처리하고 재고를 업데이트합니다.
#
# 설명: bread_type과 bread_count를 매개변수로 받아, 재고를 확인하고 충분한 경우 재고를 감소시키고 판매량을 증가시킵니다. 재고가 부족하거나 잘못된 붕어빵 종류인 경우 적절한 메시지를 출력하세요.

# %%
def process_order(self, bread_type, bread_count):
    try:
        if self.stock[bread_type] >= bread_count:
            self.stock[bread_type] -= bread_count
            self.sales[bread_type] += bread_count
            print(f"{bread_type} {bread_count}개를 판매했습니다.")
        else:
            print(f"죄송합니다. {bread_type} 재고가 부족합니다.")
    except KeyError:
        print("존재하지 않는 붕어빵 종류입니다.")

# %% [markdown]
# __[과제 4: 관리자 모드 메서드 admin_mode]__
#
# 목표: admin_mode 메서드를 구현하여 관리자 모드에서 재고를 추가할 수 있도록 합니다.
#
# 설명: bread_type과 additional_stock을 입력받아 재고를 추가합니다. 잘못된 입력 값이 들어온 경우 적절한 메시지를 출력하세요.

# %%
def admin_mode(self):
    while True:
        bread_type = input("추가할 붕어빵 종류를 입력하세요 (팥붕어빵, 슈크림붕어빵, 초코붕어빵). 종료를 원하시면 '종료'를 입력하세요: ")
        if bread_type == "종료":
            break
        try:
            additional_stock = int(input(f"{bread_type}의 추가할 개수를 입력하세요: "))
            self.stock[bread_type] += additional_stock
            print(f"{bread_type}의 재고가 {additional_stock}개 추가되었습니다.")
            self.check_stock()
        except ValueError:
            print("잘못된 입력입니다. 숫자를 입력해주세요.")
        except KeyError:
            print("존재하지 않는 붕어빵 종류입니다.")
# Out:
# 관리자 모드입니다.
# 원하는 서비스를 입력해주세요. (1:재고추가  2:매출확인  3:종료) : 1
# 현재 재고입니다. =====================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-b7f8ee88a3e3> in <cell line: 18>()
#      16         # 물품[추가] += 추가개수
#      17         # print(f'{추가}맛을 {추가개수} 개 채워 현재 재고는 {물품[추가]}개 입니다.')
# ---> 18 관리자()
#
# <ipython-input-49-8e54a052ad49> in 관리자()
#       9     if number == "1":
#      10         print("현재 재고입니다. =====================")
# ---> 11         for 종류, 개수 in self.물품.items():
#      12             print(f'{종류}의 재고는 {개수}개 입니다.')
#      13         print("===================================")
#
# NameError: name 'self' is not defined

# %% [markdown]
# __[과제 5: 매출 계산 메서드 calculate_total_sales]__
#
# 목표: calculate_total_sales 메서드를 구현하여 총 매출을 계산하고 출력합니다.
#
# 설명: self.sales와 self.prices를 사용하여 총 매출을 계산하고 출력하세요.

# %%
def calculate_total_sales(self):
    total_sales = sum(self.sales[bread] * self.prices[bread] for bread in self.sales)
    print(f"총 매출: {total_sales}원")
    print("모든 거래 내역:")
    for bread in self.sales:
        print(f"{bread} 판매: {self.sales[bread]}개, 매출: {self.sales[bread] * self.prices[bread]}원")

# %% [markdown]
# __[과제 6: 메인 함수 main]__
#
# 목표: main 함수를 작성하여 프로그램의 주요 로직을 실행합니다.
#
# 설명:
# - BungeoppangShop 객체를 생성합니다.
# - 사용자에게 모드를 선택하도록 요청합니다.
# - "주문" 모드에서는 손님의 주문을 처리하고, "관리자" 모드에서는 재고를 추가할 수 있습니다.
# - 프로그램이 종료될 때 총 매출을 계산하고 데이터를 저장합니다.

# %%
def main():
    shop = BungeoppangShop()

    while True:
        mode = input("원하는 모드를 선택하세요 (주문, 관리자, 종료): ")

        if mode == "종료":
            break

        if mode == "관리자":
            shop.admin_mode()
            continue

        if mode == "주문":
            while True:
                bread_type = input("주문할 붕어빵 종류를 입력하세요 (팥붕어빵, 슈크림붕어빵, 초코붕어빵). 종료를 원하시면 '종료'를 입력하세요: ")
                if bread_type == "종료":
                    break
                try:
                    bread_count = int(input("주문할 붕어빵 개수를 입력하세요: "))
                    shop.process_order(bread_type, bread_count)
                except ValueError:
                    print("잘못된 입력입니다. 숫자를 입력해주세요.")

                shop.check_stock()

    shop.calculate_total_sales()

if __name__ == "__main__":
    main()

# %% [markdown]
# def main():
#     while True:
#         mode = input("사용하실 시스템을 선택해주세요 (1:주문  2:관리자  3:종료) :")
#         if mode == "1":
#             주문()
#         if mode == "2":
#             관리자()
#         if mode == "3":
#             print("감사합니다 또 오세요")
#             break

# %% [markdown]
# __[과제 7: 최종 BungeoppangShop 클래스]__
#
# 함수로 리팩토링한 "붕어빵 자동 판매 시스템" 작성 후 실행합니다.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {
            "팥붕어빵": 10,
            "슈크림붕어빵": 8,
            "초코붕어빵": 5
        }
        self.prices = {
            "팥붕어빵": 1000,
            "슈크림붕어빵": 1200,
            "초코붕어빵": 1500
        }
        self.sales = {
            "팥붕어빵": 0,
            "슈크림붕어빵": 0,
            "초코붕어빵": 0
        }

    def check_stock(self):
        print("현재 붕어빵 재고:")
        for bread, quantity in self.stock.items():
            print(f"{bread}: {quantity}개")
        print('----------------------------------')

    def process_order(self, bread_type, bread_count):
        try:
            if self.stock[bread_type] >= bread_count:
                self.stock[bread_type] -= bread_count
                self.sales[bread_type] += bread_count
                print(f"{bread_type} {bread_count}개를 판매했습니다.")
                print('----------------------------------')
            else:
                print(f"죄송합니다. {bread_type} 재고가 부족합니다.")
                print('----------------------------------')
        except KeyError:
            print("존재하지 않는 붕어빵 종류입니다.")
            print('----------------------------------')

    def admin_mode(self):
        while True:
            bread_type = input("추가할 붕어빵 종류를 입력하세요 (팥붕어빵, 슈크림붕어빵, 초코붕어빵). 종료를 원하시면 '종료'를 입력하세요: ")
            if bread_type == "종료":
                break
            try:
                additional_stock = int(input(f"{bread_type}의 추가할 개수를 입력하세요: "))
                self.stock[bread_type] += additional_stock
                print(f"{bread_type}의 재고가 {additional_stock}개 추가되었습니다.")
                self.check_stock()
                print('----------------------------------')
            except ValueError:
                print("잘못된 입력입니다. 숫자를 입력해주세요.")
            except KeyError:
                print("존재하지 않는 붕어빵 종류입니다.")


    def calculate_total_sales(self):
        total_sales = sum(self.sales[bread] * self.prices[bread] for bread in self.sales)
        print(f"총 매출: {total_sales}원")
        print("모든 거래 내역:")
        for bread in self.sales:
            print(f"{bread} 판매: {self.sales[bread]}개, 매출: {self.sales[bread] * self.prices[bread]}원")

def main():
    shop = BungeoppangShop()
    while True:
        mode = input("원하는 모드를 선택하세요 (주문, 관리자, 종료): ")

        if mode == "종료":
            break

        if mode == "관리자":
            shop.admin_mode()
            continue

        if mode == "주문":
            while True:
                bread_type = input("주문할 붕어빵 종류를 입력하세요 (팥붕어빵, 슈크림붕어빵, 초코붕어빵). 종료를 원하시면 '종료'를 입력하세요: ")
                if bread_type == "종료":
                    break
                try:
                    bread_count = int(input("주문할 붕어빵 개수를 입력하세요: "))
                    shop.process_order(bread_type, bread_count)
                except ValueError:
                    print("잘못된 입력입니다. 숫자를 입력해주세요.")

                shop.check_stock()

    shop.calculate_total_sales()

if __name__ == "__main__":
    main()
# Out:
# 사용하실 시스템을 선택해주세요 (1:주문  2:관리자  3:종료) :2
# 관리자 모드입니다.
# 원하는 서비스를 입력해주세요. (1:재고추가  2:매출확인  3:종료) : 2
# {'팥붕어빵': 0, '슈크림붕어빵': 0, '초코붕어빵': 0}
# 팥붕어빵에 판매개수는 0이고 금액은 0 원 입니다.
# 슈크림붕어빵에 판매개수는 0이고 금액은 0 원 입니다.
# 초코붕어빵에 판매개수는 0이고 금액은 0 원 입니다.
# 총매출은 0입니다. 오늘 하루도 고생하셨습니다~
# 사용하실 시스템을 선택해주세요 (1:주문  2:관리자  3:종료) :3
# 감사합니다 또 오세요
