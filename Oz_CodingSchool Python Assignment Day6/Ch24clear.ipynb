# %% [markdown]
# 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info(**put):
    for key, value in put.items():
        print(f'{key}, {value}')

print_info(name="선홍", age=25, gender="남성")
# Out:
# name, 선홍
# age, 25
# gender, 남성
