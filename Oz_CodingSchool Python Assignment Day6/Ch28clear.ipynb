# %% [markdown]
# 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %%
def min_max(*number):
    tuplenumber = tuple(number)
    print("최소값 =", min(tuplenumber))
    print("최대값 =", max(tuplenumber))

min_max(1 , 3 , 5)
# Out:
# 최소값 = 1
# 최대값 = 5
