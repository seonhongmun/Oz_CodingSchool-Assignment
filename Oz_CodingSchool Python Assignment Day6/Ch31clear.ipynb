# %% [markdown]
# 문자열 리스트를 받아, 각 문자열의 길이를 출력하는 함수 print_lengths를 작성하세요.

# %%
def print_lengths(strings):
    for string in strings:
        print(len(string))
print_lengths(["app1111le", "banan2222a", "cherry"])
# Out:
# 9
# 10
# 6
