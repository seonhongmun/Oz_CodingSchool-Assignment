# %% [markdown]
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
def triangle(base, height):
    return 0.5 * base * height

def circle(radius):
    return math.pi * radius ** 2

def cuboid(length, width, height):
    return 2 * (length * width + width * height + height * length)

# %%
#실행 코드
from mymath import (triangle, circle, cuboid)

base = float(input("삼각형의 밑변 길이를 입력하세요: "))
height = float(input("삼각형의 높이를 입력하세요: "))

numbers = [1, 2, 3, 4, 5]

triangle(3, 10)
print("삼각형의 넓이:", triangle_area(base, height))

circle(4)
print("원의 넓이:", circle_area(radius))

cuboid(5, 10, 4)
print("직육면체 넓이:", cuboid_area(length, width, height))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-e6211f6f1e97> in <cell line: 2>()
#       1 #실행 코드
# ----> 2 from mathq import (triangle, circle, cuboid)
#       3
#       4 base = float(input("삼각형의 밑변 길이를 입력하세요: "))
#       5 height = float(input("삼각형의 높이를 입력하세요: "))
#
# ModuleNotFoundError: No module named 'mathq'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
