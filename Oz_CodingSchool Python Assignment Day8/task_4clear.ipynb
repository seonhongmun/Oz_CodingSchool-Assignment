# %% [markdown]
# [문제]
#
# 'Employee' 클래스를 선언하세요.
#
# 이 클래스는 월급인상률을 의미하는 클래스 변수로 'raise_amount'를 갖고 있으며, 기본값은 1.04입니다. 다음 급여는 기본 급여에 월급인상률을 곱한 값으로 결정합니다.
#
# 또한, 각 직원의 이름(name)과 급여(salary)를 속성으로 가지며, 'apply_raise' 메소드를 통해 급여에 'raise_amount'를 적용할 수 있어야 합니다.
#
# 'Employee' 클래스의 객체 두 개를 생성하고, 한 객체에만 'raise_amount'를 변경한 후, 두 객체의 급여를 증가시켜보세요.<br>
# 그리고 각 객체의 새로운 급여를 출력하세요.

# %%
class Employee:
    raise_amount = 1.04  # 클래스 변수: 기본 월급 인상률

    def __init__(self, name, salary):
        self.name = name  # 직원 이름
        self.salary = salary  # 직원 급여

    def apply_raise(self):
        # 인상률을 적용하여 급여를 업데이트
        self.salary = int(self.salary * self.raise_amount)

# 직원 객체 생성
employee1 = Employee("홍길동", 1000000)
employee2 = Employee("김철수", 1500000)

# 두 번째 직원의 월급 인상률 변경
employee2.raise_amount = 1.2

# 급여 인상 적용
employee1.apply_raise()
employee2.apply_raise()

# 결과 출력
print(f'{employee1.name}의 월급은 {employee1.salary}원입니다.')
print(f'{employee2.name}의 월급은 {employee2.salary}원입니다.')
# Out:
# 홍길동의 월급은 1040000원입니다.
# 김철수의 월급은 1800000원입니다.
