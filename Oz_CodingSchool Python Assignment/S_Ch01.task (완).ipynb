# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```인터프리트 방식에 대해 설명하고 2개 이상의 장점을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 프로그램을 실행할때 인터프리터를 이용하여 코드를 한 줄 씩 읽어나가며 실행하는 방식이다.
#
# 장점:
#  > 인터프리터를 이용하면 바로 읽어내기 때문에 프로그램의 이식성이 좋다.
#
#  > 오류 발생 시 읽던 부분에서 멈추게 되므로 오류 발견이 쉬운편이다.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```동적 타입 방식의 장점과 단점을 간략히 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 장점:
#
# > 코드 작성 시 타입(용도)에 제한이 없기 떄문에 유연성이 높고 효율적이다.
#
# 단점:
#
# > 프로그램을 실행(Run Time)때 타입(용도)에 문제를 확인할 수 있기 때문에 코드가 길고 복잡할 경우 문제 해결이 쉽지 않다.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Python으로 정적타입 방식의 코드를 작성할 수 있는 방법을 구글링을 통해 검색 후 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# mypy를 이용하여 python코드에 대한 정적타입검사를 수행하여 탕비힌트에 기반한 오류를 검출해 코드 실행전에 오류를 발견할수 있게 하여 정적타입 방식의 코드를 작성한다.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```프로세스와 스레드의 차이점을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 프로세스 : 운영체제로부터 자원을 할당받은 작업의 단위
#
# 스레드 : 프로세스가 할당받은 자원을 이용하는 실행 흐름의 단위
# 이며 프로세스와 스레드는 개념의 범위부터 다르다고 할수 이싿. 스레드는 프로세스 안에 포함되어 있기 때문이다. 프로세스는 다른 프로세스와 정보를 공유하려면 IPC를 사용하는 등의 번거로운 과정을 거쳐야 하지만, 스레드는 기본 구조 자체가 메모리를 공유하는 구조이기 때문에 다른 스레드와 정보 공유가 쉽다. 때문에 멀티태스킹보다 멀티스레드가 자원을 아낄 수 있게 된다. 다만 스레드의 스케줄링은 운영체제가 처리하지 않기 때문에 프로그래머가 직접 동기화 문제에 대응할 수 있어야 한다.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```Python 2버전대와 3버전대의 차이를 성명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# Python 2.0: 2000년에 처음 릴리즈, 2.7은 2010년
#
# Python 3.0: 2008년에 처음 릴리즈, 3.9는 2020년
#
# 바뀐 점 :
#
# >문자열 포맷 : Python3에서는 기본적으로 문자열은 Unicode이고 python2에서는 기본적으로 문자열은 ASCII 고로, Unicode시에는 "u"를 붙여야함
#
# >나누기 : Python2에서는 정수 나눗셈일 경우 가장 가까운 정수까지 반올림을 한다. (소수점이 있을 경우 반올림 X)
# 하지만 Python3 경우에는 소수점을 붙일 필요없이 계산한 결과 그대로 출력
#
# >프린트 : Python2 => print 'A', Python3 => print('A')

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제6]<br><br></span>
# ```Python에서 메모리 관리는 어떻게 이루어지는지 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 파이썬은 가비지 컬렉션과 자동 참조 카운팅 메커니즘으로 내부적으로 메모리 관리를 자동으로 처리한다.
#
# 자동 참조 카운팅 - 각 객체의 참조 카운팅이 0이 되면, 해당 객체를 자동으로 메모리에서 해제한다.
#
# 가비지 컬렉션 - 참조 카운팅만으로는 해결할 수 없는 순환 참조 문제를 해결하기 위해 주기적으로 메모리를 스캔해 객체들을 찾아내고 해제한다. gc 모듈을 통해 수동으로 실행할 수 있다.
